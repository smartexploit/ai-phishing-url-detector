# %%
import pandas as pd
import numpy as np

from pathlib import Path

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %%
DATA_PATH = Path("../data/processed/url_features.csv")

df = pd.read_csv(DATA_PATH)

print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (235795, 55)
#
# Columns:
# ['URLLength', 'DomainLength', 'IsDomainIP', 'URLSimilarityIndex', 'CharContinuationRate', 'TLDLegitimateProb', 'URLCharProb', 'TLDLength', 'NoOfSubDomain', 'HasObfuscation', 'NoOfObfuscatedChar', 'ObfuscationRatio', 'NoOfLettersInURL', 'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL', 'NoOfEqualsInURL', 'NoOfQMarkInURL', 'NoOfAmpersandInURL', 'NoOfOtherSpecialCharsInURL', 'SpacialCharRatioInURL', 'IsHTTPS', 'NoOfURLRedirect', 'NoOfSelfRedirect', 'HasExternalFormSubmit', 'HasSocialNet', 'HasSubmitButton', 'HasHiddenFields', 'HasPasswordField', 'Bank', 'Pay', 'Crypto', 'HasCopyrightInfo', 'HasFavicon', 'Robots', 'IsResponsive', 'HasTitle', 'DomainTitleMatchScore', 'URLTitleMatchScore', 'HasDescription', 'NoOfPopup', 'NoOfiFrame', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef', 'NoOfEmptyRef', 'NoOfExternalRef', 'SuspiciousCharacterDensity', 'DigitDensity', 'SubdomainDensity', 'RedirectDensity', 'ExternalReferenceRatio', 'SecurityRiskScore', 'label']

# %%
print("Label distribution:")
print(df["label"].value_counts())

print("\nLabel percentages:")
print(
    (df["label"].value_counts(normalize=True) * 100)
    .round(2)
)
# Out:
# Label distribution:
# label
# 1    134850
# 0    100945
# Name: count, dtype: int64
#
# Label percentages:
# label
# 1    57.19
# 0    42.81
# Name: proportion, dtype: float64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 1156

# %%
print("URL column available in processed dataset:", "URL" in df.columns)

if "URL" not in df.columns:
    print("URL is not present in the processed dataset.")
    print("This is expected because the processed dataset contains model features only.")
# Out:
# URL column available in processed dataset: False
# URL is not present in the processed dataset.
# This is expected because the processed dataset contains model features only.

# %%
RAW_DATA_PATH = "../data/raw/phiusiil/PhiUSIIL_Phishing_URL_Dataset.csv"

raw_df = pd.read_csv(RAW_DATA_PATH)

print("Raw dataset shape:", raw_df.shape)
print("\nRaw dataset columns:")
print(raw_df.columns.tolist())
# Out:
# Raw dataset shape: (235795, 56)
#
# Raw dataset columns:
# ['FILENAME', 'URL', 'URLLength', 'Domain', 'DomainLength', 'IsDomainIP', 'TLD', 'URLSimilarityIndex', 'CharContinuationRate', 'TLDLegitimateProb', 'URLCharProb', 'TLDLength', 'NoOfSubDomain', 'HasObfuscation', 'NoOfObfuscatedChar', 'ObfuscationRatio', 'NoOfLettersInURL', 'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL', 'NoOfEqualsInURL', 'NoOfQMarkInURL', 'NoOfAmpersandInURL', 'NoOfOtherSpecialCharsInURL', 'SpacialCharRatioInURL', 'IsHTTPS', 'LineOfCode', 'LargestLineLength', 'HasTitle', 'Title', 'DomainTitleMatchScore', 'URLTitleMatchScore', 'HasFavicon', 'Robots', 'IsResponsive', 'NoOfURLRedirect', 'NoOfSelfRedirect', 'HasDescription', 'NoOfPopup', 'NoOfiFrame', 'HasExternalFormSubmit', 'HasSocialNet', 'HasSubmitButton', 'HasHiddenFields', 'HasPasswordField', 'Bank', 'Pay', 'Crypto', 'HasCopyrightInfo', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef', 'NoOfEmptyRef', 'NoOfExternalRef', 'label']

# %%
duplicate_urls = raw_df["URL"].duplicated().sum()

print("Duplicate URLs:", duplicate_urls)

duplicate_percentage = (
    duplicate_urls / len(raw_df)
) * 100

print(f"Duplicate percentage: {duplicate_percentage:.2f}%")
# Out:
# Duplicate URLs: 425
# Duplicate percentage: 0.18%

# %%
url_label_counts = (
    raw_df.groupby("URL")["label"]
    .nunique()
)

conflicting_urls = (
    url_label_counts[url_label_counts > 1]
)

print("URLs appearing with multiple labels:", len(conflicting_urls))
# Out:
# URLs appearing with multiple labels: 0

# %%
duplicate_url_rows = raw_df[
    raw_df["URL"].duplicated(keep=False)
].sort_values("URL")

print(
    duplicate_url_rows[
        ["URL", "label"]
    ].head(20).to_string(index=False)
)
# Out:
#                                                                                        URL  label
#                                                      http://2f3a.reicrut-chat.workers.dev/      0
#                                                      http://2f3a.reicrut-chat.workers.dev/      0
#                                                                     http://34.149.138.117/      0
#                                                                     http://34.149.138.117/      0
#                            http://595221.selcdn.ru/qwerty-ohdhdjejnnad-najahhy/index4.html      0
#                            http://595221.selcdn.ru/qwerty-ohdhdjejnnad-najahhy/index4.html      0
#                            http://595221.selcdn.ru/qwerty-ohdhdjejnnad-najahhy/index8.html      0
#                            http://595221.selcdn.ru/qwerty-ohdhdjejnnad-najahhy/index8.html      0
#                                                       http://91.239.125.28/postchs/sms.php      0
#                                                       http://91.239.125.28/postchs/sms.php      0
#                http://akareal.com.vn/wp-admin/js/hku/sa/netfluinca/chun-g/account/sms2.php      0
#                http://akareal.com.vn/wp-admin/js/hku/sa/netfluinca/chun-g/account/sms2.php      0
# http://app-batasotak1244acces.kvoiffugw9-yk26ed5vg379.p.temp-site.link/termsofservice.html      0
# http://app-batasotak1244acces.kvoiffugw9-yk26ed5vg379.p.temp-site.link/termsofservice.html      0
#                                  http://app-inf0.tacbxjsspw-ypj68pkov3l2.p.temp-site.link/      0
#                                  http://app-inf0.tacbxjsspw-ypj68pkov3l2.p.temp-site.link/      0
#    http://app-mumerlah589ieks.kvoiffugw9-yk26ed5vg379.p.temp-site.link/termsofservice.html      0
#    http://app-mumerlah589ieks.kvoiffugw9-yk26ed5vg379.p.temp-site.link/termsofservice.html      0
#                                            http://app.it.185-174-136-148.cprapid.com/bper/      0
#                                            http://app.it.185-174-136-148.cprapid.com/bper/      0

# %%
import pandas as pd
import numpy as np

DATA_PATH = "../data/processed/cleaned_url_dataset.csv"

df = pd.read_csv(DATA_PATH)

print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (235370, 56)
#
# Columns:
# ['FILENAME', 'URL', 'URLLength', 'Domain', 'DomainLength', 'IsDomainIP', 'TLD', 'URLSimilarityIndex', 'CharContinuationRate', 'TLDLegitimateProb', 'URLCharProb', 'TLDLength', 'NoOfSubDomain', 'HasObfuscation', 'NoOfObfuscatedChar', 'ObfuscationRatio', 'NoOfLettersInURL', 'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL', 'NoOfEqualsInURL', 'NoOfQMarkInURL', 'NoOfAmpersandInURL', 'NoOfOtherSpecialCharsInURL', 'SpacialCharRatioInURL', 'IsHTTPS', 'LineOfCode', 'LargestLineLength', 'HasTitle', 'Title', 'DomainTitleMatchScore', 'URLTitleMatchScore', 'HasFavicon', 'Robots', 'IsResponsive', 'NoOfURLRedirect', 'NoOfSelfRedirect', 'HasDescription', 'NoOfPopup', 'NoOfiFrame', 'HasExternalFormSubmit', 'HasSocialNet', 'HasSubmitButton', 'HasHiddenFields', 'HasPasswordField', 'Bank', 'Pay', 'Crypto', 'HasCopyrightInfo', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef', 'NoOfEmptyRef', 'NoOfExternalRef', 'label']

# %%
X = df.drop(columns=["label"])
y = df["label"]

print("Feature shape:", X.shape)
print("Target shape:", y.shape)

print("\nTarget distribution:")
print(y.value_counts())
# Out:
# Feature shape: (235370, 55)
# Target shape: (235370,)
#
# Target distribution:
# label
# 1    134850
# 0    100520
# Name: count, dtype: int64

# %%
non_feature_columns = [
    "FILENAME",
    "URL",
    "Domain",
    "TLD",
    "Title"
]

print("Non-feature columns:")
for column in non_feature_columns:
    print("-", column)
# Out:
# Non-feature columns:
# - FILENAME
# - URL
# - Domain
# - TLD
# - Title

# %%
available_non_features = [
    column for column in non_feature_columns
    if column in X.columns
]

X_model = X.drop(columns=available_non_features)

print("\nModel feature shape:", X_model.shape)
print("\nModel feature data types:")
print(X_model.dtypes.value_counts())
# Out:
# Model feature shape: (235370, 50)
#
# Model feature data types:
# int64      40
# float64    10
# Name: count, dtype: int64

# %%
print("Features with only one unique value:")

constant_features = [
    column
    for column in X_model.columns
    if X_model[column].nunique() <= 1
]

print(constant_features)
# Out:
# Features with only one unique value:
# []

# %%
correlations = X_model.corrwith(y).sort_values(
    key=lambda x: x.abs(),
    ascending=False
)

print("Top feature correlations with label:")
print(correlations.head(20))
# Out:
# Top feature correlations with label:
# URLSimilarityIndex       0.860342
# HasSocialNet             0.783882
# HasCopyrightInfo         0.743197
# HasDescription           0.690011
# IsHTTPS                  0.610253
# DomainTitleMatchScore    0.584204
# HasSubmitButton          0.578816
# IsResponsive             0.548977
# URLTitleMatchScore       0.538844
# SpacialCharRatioInURL   -0.533003
# HasHiddenFields          0.507715
# HasFavicon               0.493607
# URLCharProb              0.469521
# CharContinuationRate     0.467162
# HasTitle                 0.460337
# DegitRatioInURL         -0.431896
# Robots                   0.392461
# NoOfJS                   0.373162
# LetterRatioInURL        -0.366970
# Pay                      0.359724
# dtype: float64

# %%
exact_matches = []

for column in X_model.columns:
    if X_model[column].equals(y):
        exact_matches.append(column)

print("Features identical to label:")
print(exact_matches)
# Out:
# Features identical to label:
# []

# %%
inverse_matches = []

for column in X_model.columns:
    if X_model[column].equals(1 - y):
        inverse_matches.append(column)

print("Features identical to inverse label:")
print(inverse_matches)
# Out:
# Features identical to inverse label:
# []

# %%
print("SecurityRiskScore in df:", "SecurityRiskScore" in df.columns)

print("\nEngineered features currently available:")
for feature in [
    "SuspiciousCharacterDensity",
    "DigitDensity",
    "SubdomainDensity",
    "RedirectDensity",
    "ExternalReferenceRatio",
    "SecurityRiskScore"
]:
    print(f"{feature}: {feature in df.columns}")
# Out:
# SecurityRiskScore in df: False
#
# Engineered features currently available:
# SuspiciousCharacterDensity: False
# DigitDensity: False
# SubdomainDensity: False
# RedirectDensity: False
# ExternalReferenceRatio: False
# SecurityRiskScore: False

# %%
FEATURE_PATH = "../data/processed/url_features.csv"

df_features = pd.read_csv(FEATURE_PATH)

print("Processed feature dataset shape:", df_features.shape)

print("\nSecurityRiskScore available:",
      "SecurityRiskScore" in df_features.columns)

print("\nEngineered features:")
for feature in [
    "SuspiciousCharacterDensity",
    "DigitDensity",
    "SubdomainDensity",
    "RedirectDensity",
    "ExternalReferenceRatio",
    "SecurityRiskScore"
]:
    print(f"{feature}: {feature in df_features.columns}")
# Out:
# Processed feature dataset shape: (235795, 55)
#
# SecurityRiskScore available: True
#
# Engineered features:
# SuspiciousCharacterDensity: True
# DigitDensity: True
# SubdomainDensity: True
# RedirectDensity: True
# ExternalReferenceRatio: True
# SecurityRiskScore: True

# %%
print(
    df_features.groupby("label")["SecurityRiskScore"]
    .agg(["count", "mean", "std", "min", "max"])
)
# Out:
#         count      mean       std  min  max
# label
# 0      100945  0.366764  0.640384    0    4
# 1      134850  0.935743  0.841441    0    5

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training set:", X_train.shape)
print("Testing set:", X_test.shape)
# Out:
# Training set: (188296, 55)
# Testing set: (47074, 55)

# %%
train_rows = set(map(tuple, X_train.to_numpy()))
test_rows = set(map(tuple, X_test.to_numpy()))

overlap = train_rows.intersection(test_rows)

print("Exact feature-row overlap:", len(overlap))
# Out:
# Exact feature-row overlap: 0

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

df_features = pd.read_csv("../data/processed/url_features.csv")

X = df_features.drop(columns=["label"])
y = df_features["label"]

print("X:", X.shape)
print("y:", y.shape)
# Out:
# X: (235795, 54)
# y: (235795,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))

print("\nTraining labels:")
print(y_train.value_counts())

print("\nTesting labels:")
print(y_test.value_counts())
# Out:
# Training samples: 188636
# Testing samples: 47159
#
# Training labels:
# label
# 1    107880
# 0     80756
# Name: count, dtype: int64
#
# Testing labels:
# label
# 1    26970
# 0    20189
# Name: count, dtype: int64

# %%
model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)

print("Model training complete.")
# Out:
# Model training complete.

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-score:  {f1:.4f}")
# Out:
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-score:  1.0000

# %%
print("\nClassification Report:")
print(
    classification_report(
        y_test,
        y_pred,
        target_names=["Legitimate", "Phishing"]
    )
)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   Legitimate       1.00      1.00      1.00     20189
#     Phishing       1.00      1.00      1.00     26970
#
#     accuracy                           1.00     47159
#    macro avg       1.00      1.00      1.00     47159
# weighted avg       1.00      1.00      1.00     47159

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[20189     0]
#  [    0 26970]]

# %%
engineered_features = [
    "SuspiciousCharacterDensity",
    "DigitDensity",
    "SubdomainDensity",
    "RedirectDensity",
    "ExternalReferenceRatio",
    "SecurityRiskScore"
]

# %%
X_base = X.drop(
    columns=[
        feature
        for feature in engineered_features
        if feature in X.columns
    ]
)

print("Original features:", X.shape)
print("Without engineered features:", X_base.shape)
# Out:
# Original features: (235795, 54)
# Without engineered features: (235795, 48)

# %%
X_train_base, X_test_base, y_train_base, y_test_base = train_test_split(
    X_base,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
base_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

base_model.fit(X_train_base, y_train_base)

base_pred = base_model.predict(X_test_base)

# %%
print("BASE FEATURE MODEL")
print("------------------")

print(
    f"Accuracy:  {accuracy_score(y_test_base, base_pred):.4f}"
)

print(
    f"Precision: {precision_score(y_test_base, base_pred):.4f}"
)

print(
    f"Recall:    {recall_score(y_test_base, base_pred):.4f}"
)

print(
    f"F1-score:  {f1_score(y_test_base, base_pred):.4f}"
)
# Out:
# BASE FEATURE MODEL
# ------------------
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-score:  1.0000

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Base feature model predictions
base_pred = base_model.predict(X_test_base)

base_accuracy = accuracy_score(y_test, base_pred)
base_precision = precision_score(y_test, base_pred)
base_recall = recall_score(y_test, base_pred)
base_f1 = f1_score(y_test, base_pred)

# Engineered feature model predictions
engineered_pred = engineered_model.predict(X_test_engineered)

engineered_accuracy = accuracy_score(y_test, engineered_pred)
engineered_precision = precision_score(y_test, engineered_pred)
engineered_recall = recall_score(y_test, engineered_pred)
engineered_f1 = f1_score(y_test, engineered_pred)

print("MODEL COMPARISON")
print("=" * 50)

print("\nBASE FEATURE MODEL")
print(f"Accuracy:  {base_accuracy:.4f}")
print(f"Precision: {base_precision:.4f}")
print(f"Recall:    {base_recall:.4f}")
print(f"F1-score:  {base_f1:.4f}")

print("\nENGINEERED FEATURE MODEL")
print(f"Accuracy:  {engineered_accuracy:.4f}")
print(f"Precision: {engineered_precision:.4f}")
print(f"Recall:    {engineered_recall:.4f}")
print(f"F1-score:  {engineered_f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 12
#       8 base_recall = recall_score(y_test, base_pred)
#       9 base_f1 = f1_score(y_test, base_pred)
#      10
#      11 # Engineered feature model predictions
# ---> 12 engineered_pred = engineered_model.predict(X_test_engineered)
#      13
#      14 engineered_accuracy = accuracy_score(y_test, engineered_pred)
#      15 engineered_precision = precision_score(y_test, engineered_pred)
#
# NameError: name 'engineered_model' is not defined

# %%
# %whos
# Out:
# Variable                 Type                      Data/Info
# ------------------------------------------------------------
# DATA_PATH                str                       ../data/processed/cleaned_url_dataset.csv
# FEATURE_PATH             str                       ../data/processed/url_features.csv
# Path                     type                      <class 'pathlib.Path'>
# RAW_DATA_PATH            str                       ../data/raw/phiusiil/PhiU<...>_Phishing_URL_Dataset.csv
# RandomForestClassifier   ABCMeta                   <class 'sklearn.ensemble.<...>.RandomForestClassifier'>
# X                        DataFrame                 Shape: (235795, 54)
# X_base                   DataFrame                 Shape: (235795, 48)
# X_model                  DataFrame                 Shape: (235370, 50)
# X_test                   DataFrame                 Shape: (47159, 54)
# X_test_base              DataFrame                 Shape: (47159, 48)
# X_train                  DataFrame                 Shape: (188636, 54)
# X_train_base             DataFrame                 Shape: (188636, 48)
# accuracy                 float                     1.0
# accuracy_score           function                  <function accuracy_score at 0x000001F88C8A1590>
# available_non_features   list                      n=5
# base_accuracy            float                     1.0
# base_f1                  float                     1.0
# base_model               RandomForestClassifier    RandomForestClassifier(n_<...>jobs=-1, random_state=42)
# base_precision           float                     1.0
# base_pred                ndarray                   47159: 47159 elems, type `int64`, 377272 bytes (368.4296875 kb)
# base_recall              float                     1.0
# classification_report    function                  <function classification_<...>rt at 0x000001F88C8A2AE0>
# column                   str                       NoOfExternalRef
# conflicting_urls         Series                    Shape: (0,)
# confusion_matrix         function                  <function confusion_matrix at 0x000001F88C8A16F0>
# constant_features        list                      n=0
# correlations             Series                    Shape: (50,)
# df                       DataFrame                 Shape: (235370, 56)
# df_features              DataFrame                 Shape: (235795, 55)
# duplicate_percentage     float64                   0.18024131130855192
# duplicate_url_rows       DataFrame                 Shape: (850, 56)
# duplicate_urls           int64                     425
# engineered_features      list                      n=6
# exact_matches            list                      n=0
# f1                       float                     1.0
# f1_score                 function                  <function f1_score at 0x000001F88C8A1F30>
# feature                  str                       SecurityRiskScore
# inverse_matches          list                      n=0
# model                    RandomForestClassifier    RandomForestClassifier(n_<...>jobs=-1, random_state=42)
# non_feature_columns      list                      n=5
# np                       module                    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# overlap                  set                       set()
# pd                       module                    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# precision                float                     1.0
# precision_score          function                  <function precision_score at 0x000001F88C8A26C0>
# raw_df                   DataFrame                 Shape: (235795, 56)
# recall                   float                     1.0
# recall_score             function                  <function recall_score at 0x000001F88C8A2820>
# test_rows                set                       {('843299.txt', 'https://<...> 0, 0, 0, 0, 0, 0, 0, 0)}
# train_rows               set                       {('221884.txt', 'https://<...>, 26, 13, 26, 37, 0, 29)}
# train_test_split         function                  <function train_test_split at 0x000001F88C91F690>
# url_label_counts         Series                    Shape: (235370,)
# y                        Series                    Shape: (235795,)
# y_pred                   ndarray                   47159: 47159 elems, type `int64`, 377272 bytes (368.4296875 kb)
# y_test                   Series                    Shape: (47159,)
# y_test_base              Series                    Shape: (47159,)
# y_train                  Series                    Shape: (188636,)
# y_train_base             Series                    Shape: (188636,)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Predictions from the engineered-feature model
engineered_pred = model.predict(X_test)

engineered_accuracy = accuracy_score(y_test, engineered_pred)
engineered_precision = precision_score(y_test, engineered_pred)
engineered_recall = recall_score(y_test, engineered_pred)
engineered_f1 = f1_score(y_test, engineered_pred)

print("MODEL COMPARISON")
print("=" * 50)

print("\nBASE FEATURE MODEL")
print(f"Accuracy:  {base_accuracy:.4f}")
print(f"Precision: {base_precision:.4f}")
print(f"Recall:    {base_recall:.4f}")
print(f"F1-score:  {base_f1:.4f}")

print("\nENGINEERED FEATURE MODEL")
print(f"Accuracy:  {engineered_accuracy:.4f}")
print(f"Precision: {engineered_precision:.4f}")
print(f"Recall:    {engineered_recall:.4f}")
print(f"F1-score:  {engineered_f1:.4f}")
# Out:
# MODEL COMPARISON
# ==================================================
#
# BASE FEATURE MODEL
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-score:  1.0000
#
# ENGINEERED FEATURE MODEL
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-score:  1.0000

# %%
print("FEATURE CORRELATIONS WITH LABEL")
print("=" * 50)

correlations = (
    df_features
    .corr(numeric_only=True)["label"]
    .drop("label")
    .abs()
    .sort_values(ascending=False)
)

print(correlations.head(20))
# Out:
# FEATURE CORRELATIONS WITH LABEL
# ==================================================
# URLSimilarityIndex            0.860358
# HasSocialNet                  0.784255
# HasCopyrightInfo              0.743358
# HasDescription                0.690232
# IsHTTPS                       0.609132
# DomainTitleMatchScore         0.584905
# HasSubmitButton               0.578561
# IsResponsive                  0.548608
# URLTitleMatchScore            0.539419
# SpacialCharRatioInURL         0.533537
# SuspiciousCharacterDensity    0.521377
# HasHiddenFields               0.507731
# HasFavicon                    0.493711
# URLCharProb                   0.469749
# CharContinuationRate          0.467735
# HasTitle                      0.459725
# DigitDensity                  0.432056
# DegitRatioInURL               0.432032
# Robots                        0.392620
# NoOfJS                        0.373500
# Name: label, dtype: float64

# %%
print("\nHIGH-CORRELATION FEATURES")
print("=" * 50)

high_corr = correlations[correlations >= 0.90]

if len(high_corr) == 0:
    print("No feature has absolute correlation >= 0.90 with the label.")
else:
    print(high_corr)
# Out:
# HIGH-CORRELATION FEATURES
# ==================================================
# No feature has absolute correlation >= 0.90 with the label.

# %%
print("ENGINEERED FEATURE CORRELATIONS")
print("=" * 50)

for feature in engineered_features:
    correlation = df_features[feature].corr(df_features["label"])
    print(f"{feature:30s} {correlation:.6f}")
# Out:
# ENGINEERED FEATURE CORRELATIONS
# ==================================================
# SuspiciousCharacterDensity     -0.521377
# DigitDensity                   -0.432056
# SubdomainDensity               0.249135
# RedirectDensity                0.012601
# ExternalReferenceRatio         0.107218
# SecurityRiskScore              0.346614

# %%
import joblib
from pathlib import Path

# Create models directory
models_dir = Path("../models")
models_dir.mkdir(exist_ok=True)

# Save trained model
joblib.dump(model, models_dir / "phishing_url_model.joblib")

# Save exact feature names and order
joblib.dump(list(X.columns), models_dir / "feature_names.joblib")

print("Model saved successfully.")
print("Model:", models_dir / "phishing_url_model.joblib")
print("Features:", models_dir / "feature_names.joblib")
print("Number of features:", len(X.columns))
# Out:
# Model saved successfully.
# Model: ..\models\phishing_url_model.joblib
# Features: ..\models\feature_names.joblib
# Number of features: 54
